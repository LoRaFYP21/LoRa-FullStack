# %% [markdown]
# # Data Tables Display
#
# This notebook displays the Timing Analysis and PDR data in formatted tables for easy viewing and analysis.

# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML

# Set pandas display options for better table formatting
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %% [markdown]
# ## Timing Analysis Data

# %%
# Load and display Timing Analysis data
timing_df = pd.read_csv('TimingAnalysis.csv')

print("📊 TIMING ANALYSIS DATA")
print("=" * 50)
print(f"Total records: {len(timing_df)}")
print(f"Spreading Factors: {sorted(timing_df['SF'].unique())}")
print(f"Fragment Sizes: {sorted(timing_df['Fragment Size (B)'].unique())} bytes")
print("\n")

# Style the dataframe for better display
def style_timing_table(df):
    # Create a copy to avoid modifying original
    styled_df = df.copy()
    
    # Apply styling
    styled = styled_df.style.set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#4CAF50'), 
                                           ('color', 'white'), 
                                           ('font-weight', 'bold'),
                                           ('text-align', 'center')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'),
                                           ('padding', '8px')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', "#000000")]},
        {'selector': 'tbody tr:hover', 'props': [('background-color', "#000000")]}
    ]).set_properties(**{
        'border': '1px solid #ddd',
        'font-family': 'Arial, sans-serif'
    }).format(precision=0)
    
    return styled

# Display the styled table
display(style_timing_table(timing_df))
# Out:
# 📊 TIMING ANALYSIS DATA
# ==================================================
# Total records: 24
# Spreading Factors: [np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12)]
# Fragment Sizes: [np.int64(50), np.int64(100), np.int64(150), np.int64(200)] bytes
# <style type="text/css">
# #T_cb322 thead th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_cb322 tbody td {
#   text-align: center;
#   padding: 8px;
# }
# #T_cb322 tbody tr:nth-child(even) {
#   background-color: #000000;
# }
# #T_cb322 tbody tr:hover {
#   background-color: #000000;
# }
# #T_cb322_row0_col0, #T_cb322_row0_col1, #T_cb322_row0_col2, #T_cb322_row0_col3, #T_cb322_row0_col4, #T_cb322_row0_col5, #T_cb322_row1_col0, #T_cb322_row1_col1, #T_cb322_row1_col2, #T_cb322_row1_col3, #T_cb322_row1_col4, #T_cb322_row1_col5, #T_cb322_row2_col0, #T_cb322_row2_col1, #T_cb322_row2_col2, #T_cb322_row2_col3, #T_cb322_row2_col4, #T_cb322_row2_col5, #T_cb322_row3_col0, #T_cb322_row3_col1, #T_cb322_row3_col2, #T_cb322_row3_col3, #T_cb322_row3_col4, #T_cb322_row3_col5, #T_cb322_row4_col0, #T_cb322_row4_col1, #T_cb322_row4_col2, #T_cb322_row4_col3, #T_cb322_row4_col4, #T_cb322_row4_col5, #T_cb322_row5_col0, #T_cb322_row5_col1, #T_cb322_row5_col2, #T_cb322_row5_col3, #T_cb322_row5_col4, #T_cb322_row5_col5, #T_cb322_row6_col0, #T_cb322_row6_col1, #T_cb322_row6_col2, #T_cb322_row6_col3, #T_cb322_row6_col4, #T_cb322_row6_col5, #T_cb322_row7_col0, #T_cb322_row7_col1, #T_cb322_row7_col2, #T_cb322_row7_col3, #T_cb322_row7_col4, #T_cb322_row7_col5, #T_cb322_row8_col0, #T_cb322_row8_col1, #T_cb322_row8_col2, #T_cb322_row8_col3, #T_cb322_row8_col4, #T_cb322_row8_col5, #T_cb322_row9_col0, #T_cb322_row9_col1, #T_cb322_row9_col2, #T_cb322_row9_col3, #T_cb322_row9_col4, #T_cb322_row9_col5, #T_cb322_row10_col0, #T_cb322_row10_col1, #T_cb322_row10_col2, #T_cb322_row10_col3, #T_cb322_row10_col4, #T_cb322_row10_col5, #T_cb322_row11_col0, #T_cb322_row11_col1, #T_cb322_row11_col2, #T_cb322_row11_col3, #T_cb322_row11_col4, #T_cb322_row11_col5, #T_cb322_row12_col0, #T_cb322_row12_col1, #T_cb322_row12_col2, #T_cb322_row12_col3, #T_cb322_row12_col4, #T_cb322_row12_col5, #T_cb322_row13_col0, #T_cb322_row13_col1, #T_cb322_row13_col2, #T_cb322_row13_col3, #T_cb322_row13_col4, #T_cb322_row13_col5, #T_cb322_row14_col0, #T_cb322_row14_col1, #T_cb322_row14_col2, #T_cb322_row14_col3, #T_cb322_row14_col4, #T_cb322_row14_col5, #T_cb322_row15_col0, #T_cb322_row15_col1, #T_cb322_row15_col2, #T_cb322_row15_col3, #T_cb322_row15_col4, #T_cb322_row15_col5, #T_cb322_row16_col0, #T_cb322_row16_col1, #T_cb322_row16_col2, #T_cb322_row16_col3, #T_cb322_row16_col4, #T_cb322_row16_col5, #T_cb322_row17_col0, #T_cb322_row17_col1, #T_cb322_row17_col2, #T_cb322_row17_col3, #T_cb322_row17_col4, #T_cb322_row17_col5, #T_cb322_row18_col0, #T_cb322_row18_col1, #T_cb322_row18_col2, #T_cb322_row18_col3, #T_cb322_row18_col4, #T_cb322_row18_col5, #T_cb322_row19_col0, #T_cb322_row19_col1, #T_cb322_row19_col2, #T_cb322_row19_col3, #T_cb322_row19_col4, #T_cb322_row19_col5, #T_cb322_row20_col0, #T_cb322_row20_col1, #T_cb322_row20_col2, #T_cb322_row20_col3, #T_cb322_row20_col4, #T_cb322_row20_col5, #T_cb322_row21_col0, #T_cb322_row21_col1, #T_cb322_row21_col2, #T_cb322_row21_col3, #T_cb322_row21_col4, #T_cb322_row21_col5, #T_cb322_row22_col0, #T_cb322_row22_col1, #T_cb322_row22_col2, #T_cb322_row22_col3, #T_cb322_row22_col4, #T_cb322_row22_col5, #T_cb322_row23_col0, #T_cb322_row23_col1, #T_cb322_row23_col2, #T_cb322_row23_col3, #T_cb322_row23_col4, #T_cb322_row23_col5 {
#   border: 1px solid #ddd;
#   font-family: Arial, sans-serif;
# }
# </style>
# <table id="T_cb322">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb322_level0_col0" class="col_heading level0 col0" >SF</th>
#       <th id="T_cb322_level0_col1" class="col_heading level0 col1" >Fragment Size (B)</th>
#       <th id="T_cb322_level0_col2" class="col_heading level0 col2" >Test 1 (ms)</th>
#       <th id="T_cb322_level0_col3" class="col_heading level0 col3" >Test 2 (ms)</th>
#       <th id="T_cb322_level0_col4" class="col_heading level0 col4" >Test 3 (ms)</th>
#       <th id="T_cb322_level0_col5" class="col_heading level0 col5" >Avg (ms)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb322_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb322_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_cb322_row0_col1" class="data row0 col1" >50</td>
#       <td id="T_cb322_row0_col2" class="data row0 col2" >29,567</td>
#       <td id="T_cb322_row0_col3" class="data row0 col3" >31,989</td>
#       <td id="T_cb322_row0_col4" class="data row0 col4" >30,828</td>
#       <td id="T_cb322_row0_col5" class="data row0 col5" >30,795</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb322_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_cb322_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_cb322_row1_col2" class="data row1 col2" >19,226</td>
#       <td id="T_cb322_row1_col3" class="data row1 col3" >20,229</td>
#       <td id="T_cb322_row1_col4" class="data row1 col4" >19,264</td>
#       <td id="T_cb322_row1_col5" class="data row1 col5" >19,573</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb322_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_cb322_row2_col1" class="data row2 col1" >150</td>
#       <td id="T_cb322_row2_col2" class="data row2 col2" >15,649</td>
#       <td id="T_cb322_row2_col3" class="data row2 col3" >17,639</td>
#       <td id="T_cb322_row2_col4" class="data row2 col4" >15,631</td>
#       <td id="T_cb322_row2_col5" class="data row2 col5" >16,306</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb322_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_cb322_row3_col1" class="data row3 col1" >200</td>
#       <td id="T_cb322_row3_col2" class="data row3 col2" >14,817</td>
#       <td id="T_cb322_row3_col3" class="data row3 col3" >14,928</td>
#       <td id="T_cb322_row3_col4" class="data row3 col4" >13,920</td>
#       <td id="T_cb322_row3_col5" class="data row3 col5" >14,555</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb322_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_cb322_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_cb322_row4_col2" class="data row4 col2" >53,706</td>
#       <td id="T_cb322_row4_col3" class="data row4 col3" >53,725</td>
#       <td id="T_cb322_row4_col4" class="data row4 col4" >55,040</td>
#       <td id="T_cb322_row4_col5" class="data row4 col5" >54,157</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb322_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_cb322_row5_col1" class="data row5 col1" >100</td>
#       <td id="T_cb322_row5_col2" class="data row5 col2" >35,855</td>
#       <td id="T_cb322_row5_col3" class="data row5 col3" >34,494</td>
#       <td id="T_cb322_row5_col4" class="data row5 col4" >35,496</td>
#       <td id="T_cb322_row5_col5" class="data row5 col5" >35,282</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb322_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_cb322_row6_col1" class="data row6 col1" >150</td>
#       <td id="T_cb322_row6_col2" class="data row6 col2" >28,982</td>
#       <td id="T_cb322_row6_col3" class="data row6 col3" >28,985</td>
#       <td id="T_cb322_row6_col4" class="data row6 col4" >28,999</td>
#       <td id="T_cb322_row6_col5" class="data row6 col5" >28,989</td>
#     </tr>
#     <tr>
#       <th id="T_cb322_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb322_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_cb322_row7_col1" class="data row7 col1" >200</td>
#       <td id="T_cb322_row7_col2" class="data row7 col2" >25,840</td>
#       <td id="T_cb322_row7_col3" class="data row7 col3" >24,850</td>
#       <td id="T_cb322_row7_col4" class="data row7 col4" >25,842</td>
#       <td id="T_cb322_row7_col5" class="data row7 col5" >25,511</td>
#     </tr>
#     <tr>
#       <th id="T_cb32

# %%
# Load and display PDR data
pdr_df = pd.read_csv('PDR.csv')

print("📶 PACKET DELIVERY RATIO (PDR) DATA")
print("=" * 50)
print(f"Total records: {len(pdr_df)}")
print(f"Spreading Factors: {sorted(pdr_df['SF'].unique())}")
print(f"Fragment Sizes: {sorted(pdr_df['Fragment Size (B)'].unique())} bytes")
print("\n")

# Style the PDR dataframe
def style_pdr_table(df):
    # Create a copy to avoid modifying original
    styled_df = df.copy()
    
    # Apply styling
    styled = styled_df.style.set_table_styles([
        {'selector': 'thead th', 'props': [('background-color', '#FF9800'), 
                                           ('color', 'white'), 
                                           ('font-weight', 'bold'),
                                           ('text-align', 'center')]},
        {'selector': 'tbody td', 'props': [('text-align', 'center'),
                                           ('padding', '8px')]},
        {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', "#000000")]},
        {'selector': 'tbody tr:hover', 'props': [('background-color', "#000000")]}
    ]).set_properties(**{
        'border': '1px solid #ddd',
        'font-family': 'Arial, sans-serif'
    }).format(precision=1)
    
    return styled

# Display the styled table
display(style_pdr_table(pdr_df))
# Out:
# 📶 PACKET DELIVERY RATIO (PDR) DATA
# ==================================================
# Total records: 24
# Spreading Factors: [np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12)]
# Fragment Sizes: [np.int64(50), np.int64(100), np.int64(150), np.int64(200)] bytes
# <style type="text/css">
# #T_5f8f5 thead th {
#   background-color: #FF9800;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_5f8f5 tbody td {
#   text-align: center;
#   padding: 8px;
# }
# #T_5f8f5 tbody tr:nth-child(even) {
#   background-color: #000000;
# }
# #T_5f8f5 tbody tr:hover {
#   background-color: #000000;
# }
# #T_5f8f5_row0_col0, #T_5f8f5_row0_col1, #T_5f8f5_row0_col2, #T_5f8f5_row0_col3, #T_5f8f5_row0_col4, #T_5f8f5_row0_col5, #T_5f8f5_row1_col0, #T_5f8f5_row1_col1, #T_5f8f5_row1_col2, #T_5f8f5_row1_col3, #T_5f8f5_row1_col4, #T_5f8f5_row1_col5, #T_5f8f5_row2_col0, #T_5f8f5_row2_col1, #T_5f8f5_row2_col2, #T_5f8f5_row2_col3, #T_5f8f5_row2_col4, #T_5f8f5_row2_col5, #T_5f8f5_row3_col0, #T_5f8f5_row3_col1, #T_5f8f5_row3_col2, #T_5f8f5_row3_col3, #T_5f8f5_row3_col4, #T_5f8f5_row3_col5, #T_5f8f5_row4_col0, #T_5f8f5_row4_col1, #T_5f8f5_row4_col2, #T_5f8f5_row4_col3, #T_5f8f5_row4_col4, #T_5f8f5_row4_col5, #T_5f8f5_row5_col0, #T_5f8f5_row5_col1, #T_5f8f5_row5_col2, #T_5f8f5_row5_col3, #T_5f8f5_row5_col4, #T_5f8f5_row5_col5, #T_5f8f5_row6_col0, #T_5f8f5_row6_col1, #T_5f8f5_row6_col2, #T_5f8f5_row6_col3, #T_5f8f5_row6_col4, #T_5f8f5_row6_col5, #T_5f8f5_row7_col0, #T_5f8f5_row7_col1, #T_5f8f5_row7_col2, #T_5f8f5_row7_col3, #T_5f8f5_row7_col4, #T_5f8f5_row7_col5, #T_5f8f5_row8_col0, #T_5f8f5_row8_col1, #T_5f8f5_row8_col2, #T_5f8f5_row8_col3, #T_5f8f5_row8_col4, #T_5f8f5_row8_col5, #T_5f8f5_row9_col0, #T_5f8f5_row9_col1, #T_5f8f5_row9_col2, #T_5f8f5_row9_col3, #T_5f8f5_row9_col4, #T_5f8f5_row9_col5, #T_5f8f5_row10_col0, #T_5f8f5_row10_col1, #T_5f8f5_row10_col2, #T_5f8f5_row10_col3, #T_5f8f5_row10_col4, #T_5f8f5_row10_col5, #T_5f8f5_row11_col0, #T_5f8f5_row11_col1, #T_5f8f5_row11_col2, #T_5f8f5_row11_col3, #T_5f8f5_row11_col4, #T_5f8f5_row11_col5, #T_5f8f5_row12_col0, #T_5f8f5_row12_col1, #T_5f8f5_row12_col2, #T_5f8f5_row12_col3, #T_5f8f5_row12_col4, #T_5f8f5_row12_col5, #T_5f8f5_row13_col0, #T_5f8f5_row13_col1, #T_5f8f5_row13_col2, #T_5f8f5_row13_col3, #T_5f8f5_row13_col4, #T_5f8f5_row13_col5, #T_5f8f5_row14_col0, #T_5f8f5_row14_col1, #T_5f8f5_row14_col2, #T_5f8f5_row14_col3, #T_5f8f5_row14_col4, #T_5f8f5_row14_col5, #T_5f8f5_row15_col0, #T_5f8f5_row15_col1, #T_5f8f5_row15_col2, #T_5f8f5_row15_col3, #T_5f8f5_row15_col4, #T_5f8f5_row15_col5, #T_5f8f5_row16_col0, #T_5f8f5_row16_col1, #T_5f8f5_row16_col2, #T_5f8f5_row16_col3, #T_5f8f5_row16_col4, #T_5f8f5_row16_col5, #T_5f8f5_row17_col0, #T_5f8f5_row17_col1, #T_5f8f5_row17_col2, #T_5f8f5_row17_col3, #T_5f8f5_row17_col4, #T_5f8f5_row17_col5, #T_5f8f5_row18_col0, #T_5f8f5_row18_col1, #T_5f8f5_row18_col2, #T_5f8f5_row18_col3, #T_5f8f5_row18_col4, #T_5f8f5_row18_col5, #T_5f8f5_row19_col0, #T_5f8f5_row19_col1, #T_5f8f5_row19_col2, #T_5f8f5_row19_col3, #T_5f8f5_row19_col4, #T_5f8f5_row19_col5, #T_5f8f5_row20_col0, #T_5f8f5_row20_col1, #T_5f8f5_row20_col2, #T_5f8f5_row20_col3, #T_5f8f5_row20_col4, #T_5f8f5_row20_col5, #T_5f8f5_row21_col0, #T_5f8f5_row21_col1, #T_5f8f5_row21_col2, #T_5f8f5_row21_col3, #T_5f8f5_row21_col4, #T_5f8f5_row21_col5, #T_5f8f5_row22_col0, #T_5f8f5_row22_col1, #T_5f8f5_row22_col2, #T_5f8f5_row22_col3, #T_5f8f5_row22_col4, #T_5f8f5_row22_col5, #T_5f8f5_row23_col0, #T_5f8f5_row23_col1, #T_5f8f5_row23_col2, #T_5f8f5_row23_col3, #T_5f8f5_row23_col4, #T_5f8f5_row23_col5 {
#   border: 1px solid #ddd;
#   font-family: Arial, sans-serif;
# }
# </style>
# <table id="T_5f8f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f8f5_level0_col0" class="col_heading level0 col0" >SF</th>
#       <th id="T_5f8f5_level0_col1" class="col_heading level0 col1" >Fragment Size (B)</th>
#       <th id="T_5f8f5_level0_col2" class="col_heading level0 col2" >Test 1 (%)</th>
#       <th id="T_5f8f5_level0_col3" class="col_heading level0 col3" >Test 2 (%)</th>
#       <th id="T_5f8f5_level0_col4" class="col_heading level0 col4" >Test 3 (%)</th>
#       <th id="T_5f8f5_level0_col5" class="col_heading level0 col5" >Avg (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f8f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f8f5_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_5f8f5_row0_col1" class="data row0 col1" >50</td>
#       <td id="T_5f8f5_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_5f8f5_row0_col3" class="data row0 col3" >99.6</td>
#       <td id="T_5f8f5_row0_col4" class="data row0 col4" >99.7</td>
#       <td id="T_5f8f5_row0_col5" class="data row0 col5" >99.76666667</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f8f5_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_5f8f5_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_5f8f5_row1_col2" class="data row1 col2" >99.8</td>
#       <td id="T_5f8f5_row1_col3" class="data row1 col3" >99.8</td>
#       <td id="T_5f8f5_row1_col4" class="data row1 col4" >99.8</td>
#       <td id="T_5f8f5_row1_col5" class="data row1 col5" >99.8</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f8f5_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_5f8f5_row2_col1" class="data row2 col1" >150</td>
#       <td id="T_5f8f5_row2_col2" class="data row2 col2" >99.8</td>
#       <td id="T_5f8f5_row2_col3" class="data row2 col3" >99.9</td>
#       <td id="T_5f8f5_row2_col4" class="data row2 col4" >99.9</td>
#       <td id="T_5f8f5_row2_col5" class="data row2 col5" >99.86666667</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f8f5_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_5f8f5_row3_col1" class="data row3 col1" >200</td>
#       <td id="T_5f8f5_row3_col2" class="data row3 col2" >99.9</td>
#       <td id="T_5f8f5_row3_col3" class="data row3 col3" >99.9</td>
#       <td id="T_5f8f5_row3_col4" class="data row3 col4" >99.9</td>
#       <td id="T_5f8f5_row3_col5" class="data row3 col5" >99.9</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f8f5_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_5f8f5_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_5f8f5_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_5f8f5_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_5f8f5_row4_col4" class="data row4 col4" >99.7</td>
#       <td id="T_5f8f5_row4_col5" class="data row4 col5" >99.9</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f8f5_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_5f8f5_row5_col1" class="data row5 col1" >100</td>
#       <td id="T_5f8f5_row5_col2" class="data row5 col2" >98.5</td>
#       <td id="T_5f8f5_row5_col3" class="data row5 col3" >99.2</td>
#       <td id="T_5f8f5_row5_col4" class="data row5 col4" >99.5</td>
#       <td id="T_5f8f5_row5_col5" class="data row5 col5" >99.06666667</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f8f5_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_5f8f5_row6_col1" class="data row6 col1" >150</td>
#       <td id="T_5f8f5_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_5f8f5_row6_col3" class="data row6 col3" >100</td>
#       <td id="T_5f8f5_row6_col4" class="data row6 col4" >100</td>
#       <td id="T_5f8f5_row6_col5" class="data row6 col5" >100</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5f8f5_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_5f8f5_row7_col1" class="data row7 col1" >200</td>
#       <td id="T_5f8f5_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_5f8f5_row7_col3" class="data row7 col3" >100</td>
#       <td id="T_5f8f5_row7_col4" class="data row7 col4" >100</td>
#       <td id="T_5f8f5_row7_col5" class="data row7 col5" >100</td>
#     </tr>
#     <tr>
#       <th id="T_5f8f5_level0_row8" class="row_heading level0 row8" >8</th>
